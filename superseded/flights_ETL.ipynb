# %% [markdown]
# ## SVM Quant materials

# %% [markdown]
# https://www.quantstart.com/articles/Support-Vector-Machines-A-Guide-for-Beginners/

# %% [markdown]
# ### Importing Clean Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('cleaned_filghts.csv')

# %%
df.tail(50)
# Out:
#          Unnamed: 0  YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER  \
# 5332864     5332864  2015     12    3            4      EV           2730
# 5332865     5332865  2015     12    3            4      EV           2734
# 5332866     5332866  2015     12    4            5      EV           2730
# 5332867     5332867  2015     12    4            5      EV           2734
# 5332868     5332868  2015     12    5            6      EV           2734
# 5332869     5332869  2015     12    6            7      EV           2734
# 5332870     5332870  2015     12    7            1      EV           2730
# 5332871     5332871  2015     12    7            1      EV           2734
# 5332872     5332872  2015     12    8            2      EV           2730
# 5332873     5332873  2015     12    8            2      EV           2734
# 5332874     5332874  2015     12    9            3      EV           2730
# 5332875     5332875  2015     12    9            3      EV           2734
# ...

# %%
state_totals = df.groupby(['ORIGIN_STATE']).ORIGIN_STATE.agg('count')

# %%
state_totals
# Out:
# ORIGIN_STATE
# AK     33300
# AL     26482
# AR     22654
# AS       107
# AZ    165469
# CA    647911
# CO    215451
# CT     18799
# DE       100
# FL    415586
# GA    360496
# GU       334
# HI     91181
# IA     17382
# ID     16915
# IL    381644
# IN     39107
# KS     10966
# KY     36880
# LA     65185
# MA    109290
# MD     86079
# ME      5047
# MI    137033
# MN    118701
# MO     93838
# MS     13109
# MT     14848
# NC    146906
# ND     16530
# NE     20023
# NH      6292
# NJ    108174
# NM     22241
# NV    146723
# NY    246235
# OH     74514
# OK     31445
# OR     55620
# PA     99995
# PR     26748
# RI     11058
# SC     28341
# SD      9267
# TN     75443
# TX    631124
# UT     99972
# VA    138577
# VI      5287
# VT      2978
# WA    123548
# WI     51376
# WV      2385
# WY      8218
# Name: ORIGIN_STATE, dtype: int64

# %%
airline_totals = df.groupby(['AIRLINE']).AIRLINE.agg('count')

# %%
airline_totals
# Out:
# AIRLINE
# AA     648694
# AS     158054
# B6     245135
# DL     800329
# EV     526249
# F9      82735
# HA      70030
# MQ     272650
# NK     107171
# OO     539545
# UA     469829
# US     198715
# VX      56439
# WN    1157339
# Name: AIRLINE, dtype: int64

# %% [markdown]
# ### Let's select Texas as a large state => 631,124 flights in 2015
#
# ### And Wisconsin as a 50k pa state to test the workflow!

# %%
wisconsin = df[df['ORIGIN_STATE'] == 'WI']

# %%
wisconsin.to_csv('wisconsin.csv')

# %%
big_texas = df[df['ORIGIN_STATE'] == 'TX']

# %%
big_texas.to_csv('big_texas.csv')
